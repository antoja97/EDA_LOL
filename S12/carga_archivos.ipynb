# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Cargamos todos los archivos csv, los cuales contienen cada parche de la Season 12, abarcando desde el 12.1 hasta el 12.23

# %%
p1=pd.read_csv("/Users/antoniojaenarias/Desktop/DATA SCIENCE/TODO/EDA/EDA-LOL/S12/League of Legends Champion Stats 12.1.csv",sep=";")

p13=pd.read_csv("/Users/antoniojaenarias/Desktop/DATA SCIENCE/TODO/EDA/EDA-LOL/S12/League of Legends Champion Stats 12.13.csv",sep=";")

p23=pd.read_csv("/Users/antoniojaenarias/Desktop/DATA SCIENCE/TODO/EDA/EDA-LOL/S12/League of Legends Champion Stats 12.23.csv",sep=";")

# %%
# Cargamos el archivo p1 para ver que está bien

p1
# Out:
#        Name     Class     Role Tier  Score  Trend   Win %  Role % Pick %  \
# 0    Aatrox   Fighter      TOP    A  58.25   6.52  49.97%  94.62%  4.43%
# 1      Ahri      Mage      MID    A  53.21  -0.24  49.93%  93.47%  4.62%
# 2     Akali  Assassin      MID    S  65.30   6.51  48.59%  65.65%  8.16%
# 3     Akali  Assassin      TOP    A  57.87   3.34  48.57%  34.06%  4.24%
# 4    Akshan  Marksman      MID    S  59.85   0.65  51.46%  58.01%  4.83%
# ..      ...       ...      ...  ...    ...    ...     ...     ...    ...
# 227   Ziggs      Mage      MID    C  36.44  -0.60  48.37%  24.85%  0.86%
# 228  Zilean   Support      MID    A  52.20   1.35  54.19%  14.12%  0.56%
# 229  Zilean   Support  SUPPORT    A  49.44   1.68  50.83%  81.95%  3.38%
# 230     Zoe      Mage      MID    A  49.77   4.62  49.84%  94.18%  3.62%
# 231    Zyra      Mage  SUPPORT    A  49.55   1.74  52.18%  92.46%  3.85%
#
#       Ban %   KDA
# 0     2.03%  1.97
# 1     1.04%  2.56
# 2    12.88%  2.34
# ...

# %%
p5
# Out:
#        Name     Class     Role Tier  Score  Trend   Win %  Role %  Pick %  \
# 0    Aatrox   Fighter      TOP    S  72.19  -5.85  49.43%  92.34%   7.01%
# 1      Ahri      Mage      MID  God  89.47  -5.98  51.54%  92.89%  12.50%
# 2     Akali  Assassin      MID    S  68.00  -1.60  48.85%  61.87%   7.92%
# 3     Akali  Assassin      TOP    S  59.59   3.36  48.24%  37.35%   4.53%
# 4    Akshan  Marksman      MID    A  53.74   0.80  51.51%  56.39%   3.47%
# ..      ...       ...      ...  ...    ...    ...     ...     ...     ...
# 233   Ziggs      Mage      ADC    C  37.68  -5.39  51.67%  62.80%   1.86%
# 234  Zilean   Support      MID    A  51.26   0.89  52.22%  24.03%   1.14%
# 235  Zilean   Support  SUPPORT    B  44.79  -2.95  49.63%  70.97%   3.26%
# 236     Zoe      Mage      MID    A  49.45   2.36  49.92%  91.32%   3.10%
# 237    Zyra      Mage  SUPPORT    B  45.62  -2.42  51.55%  89.15%   3.46%
#
#       Ban %   KDA
# 0     4.24%  1.89
# 1    13.82%  2.49
# 2    18.92%  2.30
# ...

# %%
# Cargamos otro archivo cualquiera para ver que está bien y además filtramos para saber aquellos
# cuyo Tier es "God" y ordenaremos a traves de Score

p23[["Tier"]]

tier_filt=p23[p23["Tier"]=="God"]
tier_score=tier_filt.sort_values(by="Score",ascending=False)
tier_score
# Out:
#             Name     Class     Role Tier  Score  Trend   Win %  Role %  \
# 104          Lux      Mage  SUPPORT  God  92.75   9.39  50.79%  69.71%
# 24       Caitlyn  Marksman      ADC  God  91.95  -0.48  49.98%  97.32%
# 45         Fiora   Fighter      TOP  God  91.89  -0.98  51.51%  96.95%
# 183        Sylas      Mage   JUNGLE  God  91.10  42.96  49.80%  48.19%
# 238        Yuumi   Support  SUPPORT  God  90.00  -3.58  47.94%  98.47%
# 0         Aatrox   Fighter      TOP  God  89.50   0.31  50.10%  90.37%
# 113    Master Yi  Assassin   JUNGLE  God  88.32  14.13  51.59%  91.97%
# 35     Dr. Mundo  Marksman      TOP  God  87.33  31.80  54.35%  75.54%
# 241          Zed  Assassin      MID  God  87.21  -4.61  49.89%  73.36%
# 118         Nami   Support  SUPPORT  God  86.67  -1.62  53.10%  99.41%
# 115  Mordekaiser   Fighter      TOP  God  86.10  10.44  51.59%  58.90%
# 205         Udyr   Fighter   JUNGLE  God  85.95  17.12  51.71%  88.42%
# ...

# %%
# Aquí vamos a mostrar aquellos que se encuentran repetidos en la columna "Name"

columna=p23["Name"]

# Filtramos para saber aquellos que aparecen repetidos y nos muestra cada fila de ellos

duplicados_name=p23.groupby("Name").filter(lambda x:len(x) > 1)
duplicados_name

# Con esto sacamos el número de nombres que aparecen repetidos, lo cual nos da 74 

repeticiones = p23.groupby("Name").size().sort_values(ascending=False)
print("Número de nombres repetidos:", len(repeticiones[repeticiones > 1]))

# Aquí mostramos el dataframe con cada uno de los 74 nombres que tienen celdas repetidas en la columna "Name" 

nombres_repetidos=duplicados_name["Name"].unique()
nombres_repetidos_df=pd.DataFrame(nombres_repetidos)
nombres_repetidos_df
# Out:
# Número de nombres repetidos: 74
#          0
# 0    Akali
# 1   Akshan
# 2    Amumu
# 3   Anivia
# 4    Annie
# ..     ...
# 69     Zac
# 70     Zed
# 71   Ziggs
# 72  Zilean
# 73     Zoe
#
# [74 rows x 1 columns]

# %%
# Vamos a eliminar la columna Trend, ya que no nos hace falta.

ls=[p1,p2,p3,p4,p5,p6,p7,p8,p9,p10,p11,p12,p13,p14,p15,p16,p17,p18,p19,p20,p21,p22,p23]

# for i in range(len(ls)):
#     ls[i] = ls[i].drop(columns=['Trend'])

p1

# El código de arriba es el realizado, pero ya no puedo ejecutarlo más, ya que han sido eliminadas.
# Out:
#        Name     Class     Role Tier  Score   Win %  Role % Pick %   Ban %  \
# 0    Aatrox   Fighter      TOP    A  58.25  49.97%  94.62%  4.43%   2.03%
# 1      Ahri      Mage      MID    A  53.21  49.93%  93.47%  4.62%   1.04%
# 2     Akali  Assassin      MID    S  65.30  48.59%  65.65%  8.16%  12.88%
# 3     Akali  Assassin      TOP    A  57.87  48.57%  34.06%  4.24%  12.88%
# 4    Akshan  Marksman      MID    S  59.85  51.46%  58.01%  4.83%  21.91%
# ..      ...       ...      ...  ...    ...     ...     ...    ...     ...
# 227   Ziggs      Mage      MID    C  36.44  48.37%  24.85%  0.86%   0.60%
# 228  Zilean   Support      MID    A  52.20  54.19%  14.12%  0.56%   1.40%
# 229  Zilean   Support  SUPPORT    A  49.44  50.83%  81.95%  3.38%   1.40%
# 230     Zoe      Mage      MID    A  49.77  49.84%  94.18%  3.62%   1.41%
# 231    Zyra      Mage  SUPPORT    A  49.55  52.18%  92.46%  3.85%   1.96%
#
#       KDA
# 0    1.97
# 1    2.56
# 2    2.34
# 3    2.04
# 4    2.23
# ...

# %%
import eda_clases
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/qg/m4_qt3hj74bcbmfymy_4_5qr0000gq/T/ipykernel_67138/151117905.py in <module>
# ----> 1 import eda_clases
#
# ModuleNotFoundError: No module named 'eda_clases'
